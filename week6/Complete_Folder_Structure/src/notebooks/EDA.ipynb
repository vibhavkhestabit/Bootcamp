# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('../data/raw/dataset.csv')
bf = pd.read_csv('../data/processed/final.csv')
    
print("--- RAW DATA (df) HEAD & TAIL ---")
display(df.head(), df.tail())
    
print("\n--- PROCESSED DATA (bf) HEAD & TAIL ---")
display(bf.head(), bf.tail())
# Out:
# --- RAW DATA (df) HEAD & TAIL ---
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
print("--- RAW DATA INFO ---")
df.info()
print("\n" + "-"*30 + "\n")
print("--- PROCESSED DATA INFO ---")
bf.info()
# Out:
# --- RAW DATA INFO ---
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB
#
# ------------------------------
#
# --- PROCESSED DATA INFO ---
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ...

# %%
# Displaying the full objects (Jupyter will provide a scrollable view)
print("Raw DataFrame Object:")
display(df)

print("Processed DataFrame Object:")
display(bf)
# Out:
# Raw DataFrame Object:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
plt.figure(figsize=(10, 6))
# Annotating the sum of missing values to add depth to the visual
sns.heatmap(df.isnull(), cbar=False, cmap='viridis', yticklabels=False)

plt.title('RAW DATA: Missing Value Heatmap (Yellow = NaN)', fontsize=14)
plt.xlabel('Features')
plt.ylabel('Observations')
plt.show()

# Print the specific counts for deeper context
print("Raw Missing Count per Column:")
print(df.isnull().sum()[df.isnull().sum() > 0])
# Out:
# Raw Missing Count per Column:
# Age         177
# Cabin       687
# Embarked      2
# dtype: int64

# %%
plt.figure(figsize=(10, 6))
# Annotating the sum of missing values to add depth to the visual
sns.heatmap(bf.isnull(), cbar=False, cmap='viridis', yticklabels=False)

plt.title('Processed DATA: Missing Value Heatmap (Yellow = NaN)', fontsize=14)
plt.xlabel('Features')
plt.ylabel('Observations')
plt.show()

# Print the specific counts for deeper context
print("Processed Missing Count per Column:")
print(bf.isnull().sum()[bf.isnull().sum() > 0])
# Out:
# Processed Missing Count per Column:
# Series([], dtype: int64)

# %%
plt.figure(figsize=(12, 8))
# Using bf (processed) as it usually contains the encoded numeric features
numeric_bf = bf.select_dtypes(include=[np.number])
sns.heatmap(numeric_bf.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix (Processed Data)')
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='Survived', data=df, palette='viridis')
plt.title('Target Distribution: Survived (1) vs Deceased (0)')

# Print percentages for deep analysis
print("Class Percentages:\n", df['Survived'].value_counts(normalize=True) * 100)
plt.show()
# Out:
# Class Percentages:
#  Survived
# 0    61.616162
# 1    38.383838
# Name: proportion, dtype: float64
# /tmp/ipykernel_158829/764231946.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Survived', data=df, palette='viridis')

# %%
numeric_raw = df.select_dtypes(include=[np.number]).drop(columns=['PassengerId', 'Survived'], errors='ignore')
numeric_raw.hist(figsize=(15, 10), bins=30, color='skyblue', edgecolor='black')
plt.suptitle('Raw Data: Numerical Distributions', fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
numeric_proc = bf.select_dtypes(include=[np.number]).drop(columns=['Survived'], errors='ignore')
numeric_proc.hist(figsize=(15, 10), bins=30, color='salmon', edgecolor='black')
plt.suptitle('Processed Data: Numerical Distributions', fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
skewness_values = bf.select_dtypes(include=[np.number]).skew()

print("Skewness in Features:")
print(skewness_values.sort_values(ascending=False))
# Out:
# Skewness in Features:
# Fare        4.787317
# SibSp       3.695352
# Parch       2.749117
# Age         0.510245
# Survived    0.478523
# Pclass     -0.630548
# dtype: float64

# %%
df.shape
# Out:
# (891, 12)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Check for outliers in 'Fare' and 'Age'
plt.figure(figsize=(10, 5))
sns.boxplot(data=df[['Age', 'Fare']], palette="Set2")
plt.title("Outlier Detection using Box Plots")
plt.show()

# %%
plt.figure(figsize=(12, 6))

# 1. Compare Fare vs Pclass
plt.subplot(1, 2, 1)
sns.boxplot(x='Pclass', y='Fare', data=df)
plt.title('Outliers: Fare vs Passenger Class')

# 2. Compare Age vs Survived
plt.subplot(1, 2, 2)
sns.boxplot(x='Survived', y='Age', data=df)
plt.title('Outliers: Age vs Survival Status')

plt.tight_layout()
plt.show()

# %%
# 1. Get the exact raw numbers
raw_counts = bf['Survived'].value_counts()
print("--- Exact Passenger Counts ---")
print(raw_counts)

# 2. Get the percentages (normalize=True gives fractions, multiply by 100 for %)
percentages = bf['Survived'].value_counts(normalize=True) * 100
print("\n--- Class Percentages ---")
print(percentages.round(2))
# Out:
# --- Exact Passenger Counts ---
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64
#
# --- Class Percentages ---
# Survived
# 0    61.62
# 1    38.38
# Name: proportion, dtype: float64
